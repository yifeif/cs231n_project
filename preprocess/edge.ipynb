# %%
################################################################################
# Note book to check edge detection result on a random input image
################################################################################
import os, random
from shutil import copyfile
import numpy as np
import matplotlib.pyplot as plt
from scipy.misc import imread

# This is a bit of magic to make matplotlib figures appear inline in the notebook
# rather than in a new window.
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20.0, 20.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from data_utils import preprocess_rawrgb
f = [os.path.join(dp, f) for dp, dn, filenames in os.walk('../dataset') for f in filenames if os.path.splitext(f)[1] == '.png']

# %%
################################
# Re-run this cell for new image
################################
image_path = random.choice(f)

copyfile(image_path, 'car_sample.png')
rgb = imread('car_sample.png')

preprocess_rawrgb('car_sample.png')
rgb_padded = imread('car_sample_padded.png')
edge = np.load('car_sample.npy')
edge_padded = np.load('car_sample_padded.npy')
images_to_show = [rgb, rgb_padded, edge, edge_padded]
for i in range(4):
    plt.subplot(1, 4, i + 1)
    plt.imshow(images_to_show[i])
